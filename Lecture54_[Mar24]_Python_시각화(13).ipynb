# %% [markdown]
# # Pandas 내장 그래프 도구
#
# - 판다스는 `matplotlib` 라이브러리 기능을 일부 내장하고 있어서 별도로 import 하지 않고 간단히 그래프 그릴 수 있음
# - `plot()` : 선그래프
# - `plot(kind='bar')` : 막대그래프
# - `plot(kind='hist')` : 히스토그램
# - `plot(x='', y='', kind='scatter')` : 산점도, 상관관계 분석시 활용
# - `plot(kind='box')` : 박스플롯, 특정 변수의 데이터 분포와 분산 정도에 대한 정보 제공
#
# [`pandas.DataFrame.plot > kind=`](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html)
# - `line` : line plot (default)
# - `bar` : vertical bar plot
# - `barh` : horizontal bar plot
# - `hist` : histogram
# - `box` : boxplot
# - `kde` : Kernel Density Estimation plot
# - `density` : same as `kde`
# - `area` : area plot
# - `pie` : pie plot
# - `scatter` : scatter plot
# - `hexbin` : hexbin plot

# %%
import pandas as pd

df = pd.read_excel('/content/남북한발전전력량.xlsx')

display (df.head(10))

df_ns = df.iloc[[0,5], 2:]
df_ns.index = ['SK','NK']
df_ns.columns = df_ns.columns.astype(int)
display (df_ns)
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
# 3       NaN    원자력   529   563   565   581  ...  1547  1503  1388  1564  1648  1620
# 4       NaN    신재생     -     -     -     -  ...     -    86   118   151   173   195
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
# 6       NaN     수력   156   150   142   133  ...   132   135   139   130   100   128
# 7       NaN     화력   121   113   105    88  ...    79    80    82    86    90   111
# 8       NaN    원자력     -     -     -     -  ...     -     -     -     -     -     -
#
# [9 rows x 29 columns]
#     1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# ...

# %%
print (df_ns.plot(), '\n')
print (df_ns.T.plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
tdf_ns = df_ns.T
print (tdf_ns.SK.head())
display (tdf_ns['SK'].head())
display (tdf_ns.loc[:, ['SK']].head())
# Out:
# 1990    1077
# 1991    1186
# 1992    1310
# 1993    1444
# 1994    1650
# Name: SK, dtype: object
# 1990    1077
# 1991    1186
# 1992    1310
# 1993    1444
# 1994    1650
# Name: SK, dtype: object
#         SK
# 1990  1077
# 1991  1186
# 1992  1310
# 1993  1444
# 1994  1650

# %%
print (tdf_ns.plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# histogram 은 주로 하나의 index에 대해서 분포도를 볼 때

# %%
print (tdf_ns.plot(kind='hist'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print (tdf_ns['SK'].plot(kind='hist'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df = pd.read_csv('auto-mpg.csv', header=None)

df.columns = ['mpg','cylinders','displacement','horsepower','weight','acceleration','model_year','origin','name']
df_s = df[['mpg','cylinders','weight','displacement','acceleration',]]
df_s.head()
# Out:
#     mpg  cylinders  weight  displacement  acceleration
# 0  18.0          8  3504.0         307.0          12.0
# 1  15.0          8  3693.0         350.0          11.5
# 2  18.0          8  3436.0         318.0          11.0
# 3  16.0          8  3433.0         304.0          12.0
# 4  17.0          8  3449.0         302.0          10.5

# %%
display (df.corr())

display (df_s.corr(), '\n')
# Out:
#                    mpg  cylinders  ...  model_year    origin
# mpg           1.000000  -0.775396  ...    0.579267  0.563450
# cylinders    -0.775396   1.000000  ...   -0.348746 -0.562543
# displacement -0.804203   0.950721  ...   -0.370164 -0.609409
# weight       -0.831741   0.896017  ...   -0.306564 -0.581024
# acceleration  0.420289  -0.505419  ...    0.288137  0.205873
# model_year    0.579267  -0.348746  ...    1.000000  0.180662
# origin        0.563450  -0.562543  ...    0.180662  1.000000
#
# [7 rows x 7 columns]
#                    mpg  cylinders    weight  displacement  acceleration
# mpg           1.000000  -0.775396 -0.831741     -0.804203      0.420289
# cylinders    -0.775396   1.000000  0.896017      0.950721     -0.505419
# weight       -0.831741   0.896017  1.000000      0.932824     -0.417457
# displacement -0.804203   0.950721  0.932824      1.000000     -0.543684
# acceleration  0.420289  -0.505419 -0.417457     -0.543684      1.000000
# '\n'

# %%
df_s.plot(kind='scatter', x='weight', y='mpg')

# %%
df_s.plot(kind='scatter', x='displacement', y='cylinders')

# %%
df_s.plot(kind='scatter', y='mpg', x='cylinders')

# %%
df_s.plot(kind='scatter', x='displacement', y='mpg')

# %%
df_s.plot(kind='scatter', y='mpg', x='acceleration')

# %% [markdown]
# # `matplotlib` 활용한 시각화
#
# - `sns.set_style('{ darkgrid/whitegrid/dark/white/ticks }')`

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

titanic = sns.load_dataset('titanic')
sns.set_style("darkgrid")
# sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})

# 그래프 객체 2개 생성
fig = plt.figure(figsize=(15,5))

# (1,2,1) :  1행 2열의 1번째
ax1 = fig.add_subplot(1,2,1)

# (1,2,2) :  1행 2열의 2번째
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='age', y='fare', data=titanic, ax=ax1, fit_reg=True)
sns.regplot(x='age', y='fare', data=titanic, ax=ax2, fit_reg=False)

plt.show()
