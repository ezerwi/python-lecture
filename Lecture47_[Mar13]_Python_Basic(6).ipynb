# %% [markdown]
# ### Lecture46 Mar/12/2020

# %% [markdown]
# Pandas

# %% [markdown]
# 행렬벡터, 열벡터
#
# Scala, Vector, Matrix
#
# 행벡터 : 1 X m  // 열벡터 : n X 1
#
# M X N 행렬
#
#
# 시리즈, 데이터프레임
#
#
# 벡터화 연산을 사용하면 for loop이 아닌 덧셈 연산으로 빠르게 끝낼 수 있음,
# * `%%time` 을 통해 셀 코드의 실행시간 측정 가능

# %%
import pandas as pd

# %% [markdown]
# ## 자료구조
#
# ### `pandas.Series`
#
# - series는 1차원 배열, data frame은 2차원 배열 ; 대표적인 class object
# - series index는 data 값과 1:1 대응, dictionary와 유사 구조
#
#
# - series data type of values == int64

# %%
dict_data = {'a' : 1, 'b' : 2, 'c' : 3}
sr = pd.Series(dict_data)

# dictionary type to pandas.Series
print (type(sr), "\n")

print (sr)
# Out:
# <class 'pandas.core.series.Series'>
#
# a    1
# b    2
# c    3
# dtype: int64
