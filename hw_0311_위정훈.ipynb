# %% [markdown]
# <a href="https://colab.research.google.com/github/ezerwi/python-lecture/blob/master/hw_0311_%EC%9C%84%EC%A0%95%ED%9B%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 1. 다음은 학생 성적 관리 프로그램으로 리스트와 딕셔너리로 표현하고 for문을 사용해서 학생별 총점과 평균을 구했다. 딕셔너리로 객체를 각각 만드니 번거롭고 실수가 발생될 가능성이 높았다. Student 클래스를 만들고 각 학생 객체로 구성되는 학생 리스트를 작성하여 for문을 이용하여 출력하는 방식으로 프로그램을 개선 하세요.

# %%
# 학생 리스트를 선언합니다.
students = [
    { "name": "조인성", "korean": 87, "math": 98, "english": 88, "science": 95 },
    { "name": "연하진", "korean": 92, "math": 98, "english": 96, "science": 98 },
    { "name": "구지연", "korean": 76, "math": 96, "english": 94, "science": 90 },
    { "name": "나선주", "korean": 98, "math": 92, "english": 96, "science": 92 },
    { "name": "윤아린", "korean": 95, "math": 98, "english": 98, "science": 98 },
    { "name": "윤명월", "korean": 64, "math": 88, "english": 92, "science": 92 }
]

# 학생을 한 명씩 반복합니다.
print("이름", "총점", "평균", sep="\t")
for student in students:
    # 점수의 총합과 평균을 구합니다.
    score_sum = student["korean"] + student["math"] +\
        student["english"] + student["science"]
    score_average = score_sum / 4
    # 출력합니다.
    print(student["name"], score_sum, score_average, sep="\t")
# Out:
# 이름	총점	평균
# 조인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %%
class Student :
    sum, avg = 0, 0
    ss = ['korean', 'math', 'english', 'science']
    def __init__(self, stu) :
        self.stu = stu
    def make_sum(self) :
        for i in self.ss :
            self.sum += self.stu[i]
        return self.sum
    def make_avg(self) :
        return self.sum / len(self.ss)

print("이름", "총점", "평균", sep="\t")
for i in students:
    stu = Student(i)
    print (i['name'], end="\t")
    print (stu.make_sum(), end="\t")
    print (stu.make_avg())
# Out:
# 이름	총점	평균
# 조인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %% [markdown]
# #### 2. 원의 둘레와 넓이를 구하는 메소드를 포함하고 있는 Circle 클래스를 활용해서 반지름이 10인 원의 둘레와 넓이를 구하세요.

# %%
import math

class Circle:
    def __init__(self, ban):
        self.ban = ban
    def area(self) :
        return math.pi*self.ban*self.ban
    def leng(self) :
        return math.pi*self.ban*2

c = Circle(10)
print ('둘레 : ', c.leng())
print ('넓이 : ', c.area())
# Out:
# 둘레 :  62.83185307179586
# 넓이 :  314.1592653589793

# %% [markdown]
# #### 3. 랜덤하게 1000명의 키와 몸무게를 파일 쓰기모드로 작성 후 저장하세요.

# %%
import random
fw = open ('test.txt', 'w')
for i in range(1000) :
    person = str({'키' : random.randint(100, 250) , '몸무게' : random.randint(30, 200)})+'\n'
    fw.write(person)
fw.close()

# fr = open ('test.txt', 'r')
# while True :
#     line = fr.readline()
#     if not line : break
#     print (line)
# fr.close()

# %% [markdown]
# #### 4. 3번에서 작성한 1000명의 키와 몸무게로 BMI(비만도)를 계산해서 저체중, 과체중, 정상체중으로 분류해서 출력하세요.
# BMI = int(weight) / ((int(height) / 100) **2)

# %%
fr = open ('test.txt', 'r')
line=""
i=0
while True :
    line = fr.readline()
    if not line : break
    height = int(line[6:9])
    weight = int(line[-5:-2])
    print('키 : ', height,'\t몸무게 : ', weight, end="\t")
    BMI = weight/(height/100)**2
    print ('BMI = %0.3f'% BMI, end="\t")
    if BMI >= 25 : print('과체중')
    elif BMI < 18.5 : print('저체중')
    else : print('정상체중')
fr.close()
# Out:
# 키 :  242 	몸무게 :  58	BMI = 9.904	저체중
# 키 :  160 	몸무게 :  33	BMI = 12.891	저체중
# 키 :  169 	몸무게 :  153	BMI = 53.570	과체중
# 키 :  160 	몸무게 :  81	BMI = 31.641	과체중
# 키 :  176 	몸무게 :  136	BMI = 43.905	과체중
# 키 :  242 	몸무게 :  64	BMI = 10.928	저체중
# 키 :  105 	몸무게 :  163	BMI = 147.846	과체중
# 키 :  190 	몸무게 :  34	BMI = 9.418	저체중
# 키 :  131 	몸무게 :  142	BMI = 82.746	과체중
# 키 :  235 	몸무게 :  129	BMI = 23.359	정상체중
# 키 :  100 	몸무게 :  190	BMI = 190.000	과체중
# 키 :  120 	몸무게 :  161	BMI = 111.806	과체중
# 키 :  219 	몸무게 :  31	BMI = 6.464	저체중
# 키 :  205 	몸무게 :  138	BMI = 32.838	과체중
# 키 :  192 	몸무게 :  41	BMI = 11.122	저체중
# 키 :  225 	몸무게 :  193	BMI = 38.123	과체중
# 키 :  161 	몸무게 :  149	BMI = 57.482	과체중
# 키 :  150 	몸무게 :  75	BMI = 33.333	과체중
# 키 :  110 	몸무게 :  135	BMI = 111.570	과체중
# 키 :  244 	몸무게 :  110	BMI = 18.476	저체중
# 키 :  193 	몸무게 :  71	BMI = 19.061	정상체중
# 키 :  210 	몸무게 :  137	BMI = 31.066	과체중
# 키 :  168 	몸무게 :  74	BMI = 26.219	과체중
# 키 :  125 	몸무게 :  103	BMI = 65.920	과체중
# 키 :  224 	몸무게 :  52	BMI = 10.364	저체중
# ...

# %% [markdown]
# #### 5. 재귀함수를 이용해 다음 팩토리얼을 출력하세요.
# 1!: \
# 2!: \
# 3!: \
# 4!: \
# 5!:

# %%
def facto(num) :
    if num == 1 : return num
    return num*facto(num-1)
    
print( facto (1))
print (facto (2))
print (facto (3))
print (facto (4))
print (facto (5))
# Out:
# 1
# 2
# 6
# 24
# 120
